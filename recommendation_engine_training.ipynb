# %% [markdown]
# This notebook will be used as an input for our recommendation agent. We are going to base the recommendations on the previous transactions.

# %%
import pandas as pd 
from mlxtend.frequent_patterns import association_rules, apriori

# %% [markdown]
# # Read Dataset

# %%
sales_reciepts = pd.read_csv('dataset/201904_sales_reciepts.csv')

# %%
sales_reciepts.head()
# Out:
#    transaction_id transaction_date transaction_time  sales_outlet_id  \
# 0               7       2019-04-01         12:04:43                3
# 1              11       2019-04-01         15:54:39                3
# 2              19       2019-04-01         14:34:59                3
# 3              32       2019-04-01         16:06:04                3
# 4              33       2019-04-01         19:18:37                3
#
#    staff_id  customer_id instore_yn  order  line_item_id  product_id  \
# 0        12          558          N      1             1          52
# 1        17          781          N      1             1          27
# 2        17          788          Y      1             1          46
# 3        12          683          N      1             1          23
# 4        17           99          Y      1             1          34
#
#    quantity  line_item_amount  unit_price promo_item_yn
# 0         1              2.50        2.50             N
# 1         2              7.00        3.50             N
# 2         2              5.00        2.50             N
# 3         2              5.00        2.50             N
# 4         1              2.45        2.45             N

# %%
product = pd.read_csv('dataset/product.csv')

# %%
product.head()
# Out:
#    Unnamed: 0  product_id    product_group product_category  \
# 0           0           1  Whole Bean/Teas     Coffee beans
# 1           1           2  Whole Bean/Teas     Coffee beans
# 2           2           3  Whole Bean/Teas     Coffee beans
# 3           3           4  Whole Bean/Teas     Coffee beans
# 4           4           5  Whole Bean/Teas     Coffee beans
#
#         product_type                   product  \
# 0      Organic Beans       Brazilian - Organic
# 1  House blend Beans  Our Old Time Diner Blend
# 2     Espresso Beans            Espresso Roast
# 3     Espresso Beans      Primo Espresso Roast
# 4      Gourmet Beans    Columbian Medium Roast
#
#                                  product_description unit_of_measure  \
# 0     It's like Carnival in a cup. Clean and smooth.           12 oz
# 1  Out packed blend of beans that is reminiscent ...           12 oz
# 2          Our house blend for a good espresso shot.            1 lb
# 3   Our primium single source of hand roasted beans.            1 lb
# 4           A smooth cup of coffee any time of day.             1 lb
#
#    current_wholesale_price current_retail_price tax_exempt_yn promo_yn  \
# 0                    14.40              $18.00              Y        N
# 1                    14.40              $18.00              Y        N
# 2                    11.80              $14.75              Y        N
# 3                    16.36              $20.45              Y        N
# 4                    12.00              $15.00              Y        N
#
#   new_product_yn
# 0              N
# 1              N
# 2              N
# 3              N
# 4              N

# %% [markdown]
# # Data Merging

# %%
dataset = pd.merge(sales_reciepts[['transaction_id','transaction_date', 'sales_outlet_id', 'customer_id', 'product_id', 'quantity']],
                    product[['product_id', 'product_category', 'product']],
                    on ='product_id', how = 'left'
                )

# %%
dataset.head()
# Out:
#    transaction_id transaction_date  sales_outlet_id  customer_id  product_id  \
# 0               7       2019-04-01                3          558          52
# 1              11       2019-04-01                3          781          27
# 2              19       2019-04-01                3          788          46
# 3              32       2019-04-01                3          683          23
# 4              33       2019-04-01                3           99          34
#
#    quantity product_category                      product
# 0         1              Tea    Traditional Blend Chai Rg
# 1         2           Coffee                 Brazilian Lg
# 2         2              Tea        Serenity Green Tea Rg
# 3         2           Coffee  Our Old Time Diner Blend Rg
# 4         1           Coffee     Jamaican Coffee River Sm

# %%
# Remove sizes 
dataset['product'] = dataset['product'].str.replace(' Rg', '')
dataset['product'] = dataset['product'].str.replace(' Sm', '')
dataset['product'] = dataset['product'].str.replace(' Lg', '')

# %%
dataset.head(2)
# Out:
#    transaction_id transaction_date  sales_outlet_id  customer_id  product_id  \
# 0               7       2019-04-01                3          558          52
# 1              11       2019-04-01                3          781          27
#
#    quantity product_category                 product
# 0         1              Tea  Traditional Blend Chai
# 1         2           Coffee               Brazilian

# %%
# Choose product
products_to_take = ['Cappucin', 'Direct', 'Espresso shot',  \
                     'Dark chocolate','Sugar Free Vanilla syrup', 'Chocolate syrup',\
                    'Carmel syrup', 'Hazelnut syrup', 'Ginger Scone',  \
                    'Chocolate Croissant', 'Jumbo Savory Scone', 'Cranberry Scone', 'Hazelnut Biscotti',\
                    'Croissant', 'Almond Croissant', 'Oatmeal Scone', 'Chocolate Chip Biscotti',\
                    'Ginger Biscotti',\
                   ]
dataset = dataset[dataset['product'].isin(products_to_take)]

# %%
# Clean transactions 
dataset['transaction'] = dataset['transaction_id'].astype(str) + "_" + dataset['customer_id'].astype(str)
num_of_items_for_each_transaction = dataset['transaction'].value_counts().reset_index()
valid_transactions = num_of_items_for_each_transaction[(num_of_items_for_each_transaction['count']>1)]['transaction'].tolist()
dataset = dataset[dataset['transaction'].isin(valid_transactions)]

# %% [markdown]
# # Recommendation Engine

# %%
# Popularity recommendation engine 
popularity_recommendation = dataset.groupby(['product','product_category']).count().reset_index()
popularity_recommendation = popularity_recommendation[['product','product_category','transaction_id']]
popularity_recommendation = popularity_recommendation.rename(columns = {'transaction_id':'number_of_transactions'})
popularity_recommendation.to_csv('api/recommendation_objects/popularity_recommendation.csv',index=False)

# %%
# Apriori recommendation engine 
train_basket = dataset.groupby(['transaction','product'])['product'].count().reset_index(name='Count')
train_basket.head(10)
# Out:
#   transaction          product  Count
# 0      1000_0   Dark chocolate      1
# 1      1000_0    Oatmeal Scone      1
# 2   1001_8306         Cappucin      1
# 3   1001_8306     Carmel syrup      1
# 4      1002_0     Carmel syrup      1
# 5      1002_0   Dark chocolate      2
# 6      1002_0    Espresso shot      1
# 7      1002_0     Ginger Scone      1
# 8   1004_5383  Chocolate syrup      1
# 9   1004_5383           Direct      1

# %%
my_basket = train_basket.pivot_table(index='transaction', columns='product', values='Count',aggfunc='sum').fillna(0)
my_basket.head()
# Out:
# product      Almond Croissant  Cappucin  Carmel syrup  \
# transaction
# 1000_0                    0.0       0.0           0.0
# 1001_8306                 0.0       1.0           1.0
# 1002_0                    0.0       0.0           1.0
# 1004_5383                 0.0       0.0           0.0
# 1005_0                    0.0       0.0           0.0
#
# product      Chocolate Chip Biscotti  Chocolate Croissant  Chocolate syrup  \
# transaction
# 1000_0                           0.0                  0.0              0.0
# 1001_8306                        0.0                  0.0              0.0
# 1002_0                           0.0                  0.0              0.0
# 1004_5383                        0.0                  0.0              1.0
# 1005_0                           0.0                  0.0              0.0
#
# product      Cranberry Scone  Croissant  Dark chocolate  Direct  \
# transaction
# 1000_0                   0.0        0.0             1.0     0.0
# 1001_8306                0.0        0.0             0.0     0.0
# 1002_0                   0.0        0.0             2.0     0.0
# 1004_5383                0.0        0.0             0.0     1.0
# 1005_0                   0.0        0.0             0.0     1.0
#
# product      Espresso shot  Ginger Biscotti  Ginger Scone  Hazelnut Biscotti  \
# transaction
# 1000_0                 0.0              0.0           0.0                0.0
# 1001_8306              0.0              0.0           0.0                0.0
# 1002_0                 1.0              0.0           1.0                0.0
# 1004_5383              0.0              0.0           0.0                0.0
# 1005_0                 0.0              0.0           0.0                0.0
#
# product      Hazelnut syrup  Jumbo Savory Scone  Oatmeal Scone  \
# transaction
# 1000_0                  0.0                 0.0            1.0
# 1001_8306               0.0                 0.0            0.0
# 1002_0                  0.0                 0.0            0.0
# 1004_5383               0.0                 0.0            0.0
# 1005_0                  0.0                 2.0            0.0
#
# product      Sugar Free Vanilla syrup
# transaction
# 1000_0                            0.0
# 1001_8306                         0.0
# 1002_0                            0.0
# 1004_5383                         0.0
# 1005_0                            0.0

# %%
def encode_units(x):
  if x <= 0:
    return 0
  if x >= 0:
    return 1

my_basket_sets = my_basket.applymap(encode_units)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18628\1492677825.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   my_basket_sets = my_basket.applymap(encode_units)

# %%
frequent_items = apriori(my_basket_sets, min_support = 0.05, use_colnames=True)
frequent_items.head()
# Out:
# c:\Amine\GenAI\Projects\coffee\venv\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                   itemsets
# 0  0.132471         (Almond Croissant)
# 1  0.247993                 (Cappucin)
# 2  0.193131             (Carmel syrup)
# 3  0.125781  (Chocolate Chip Biscotti)
# 4  0.156557      (Chocolate Croissant)

# %%
rules_basket = association_rules(frequent_items, metric = "lift", min_threshold=1)
rules_basket.head()
# Out:
#           antecedents         consequents  antecedent support  \
# 0    (Dark chocolate)  (Almond Croissant)            0.323818
# 1  (Almond Croissant)    (Dark chocolate)            0.132471
# 2      (Carmel syrup)          (Cappucin)            0.193131
# 3          (Cappucin)      (Carmel syrup)            0.247993
# 4          (Cappucin)   (Chocolate syrup)            0.247993
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.132471  0.067797    0.209366  1.580470               1.0
# 1            0.323818  0.067797    0.511785  1.580470               1.0
# 2            0.247993  0.066905    0.346420  1.396896               1.0
# 3            0.193131  0.066905    0.269784  1.396896               1.0
# 4            0.196253  0.075825    0.305755  1.557963               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.024900    1.097258       0.543162  0.174512   0.088637    0.360575
# 1  0.024900    1.385007       0.423359  0.174512   0.277982    0.360575
# 2  0.019009    1.150597       0.352136  0.178784   0.130886    0.308102
# 3  0.019009    1.104973       0.377825  0.178784   0.095001    0.308102
# 4  0.027156    1.157728       0.476240  0.205811   0.136240    0.346060

# %%
rules_basket.to_pickle('rules_basket.pkl')

# %% [markdown]
# # Save in Json Format

# %%
product_categories = dataset[['product','product_category']].drop_duplicates().set_index('product').to_dict()['product_category']

# %%
recommendations_json = {}
antecedents = rules_basket['antecedents'].unique()
for antecedent in antecedents: 
    df_rec = rules_basket[rules_basket['antecedents']==antecedent]
    df_rec = df_rec.sort_values('confidence', ascending = False)
    key = "_".join(antecedent)
    recommendations_json[key] = []
    for _, row in df_rec.iterrows():
        rec_objects =row['consequents']
        for rec_object in rec_objects:
            already_exists = False
            for current_rec_object in recommendations_json[key]:
                if rec_object == current_rec_object['product']:
                    already_exists=True
            if already_exists:
                continue
            
            rec = {'product':rec_object, 
                   'product_category':product_categories[rec_object],
                   'confidence': row['confidence']
                  }
            recommendations_json[key].append(rec)

# %%
import pprint
pprint.pp(recommendations_json)
# Out:
# {'Dark chocolate': [{'product': 'Chocolate Croissant',
#                      'product_category': 'Bakery',
#                      'confidence': 0.2190082644628099},
#                     {'product': 'Ginger Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.21763085399449036},
#                     {'product': 'Almond Croissant',
#                      'product_category': 'Bakery',
#                      'confidence': 0.209366391184573},
#                     {'product': 'Cranberry Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.20523415977961432},
#                     {'product': 'Carmel syrup',
#                      'product_category': 'Flavours',
#                      'confidence': 0.20110192837465563},
#                     {'product': 'Chocolate Chip Biscotti',
#                      'product_category': 'Bakery',
#                      'confidence': 0.19559228650137742},
#                     {'product': 'Jumbo Savory Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.18732782369146006},
#                     {'product': 'Croissant',
#                      'product_category': 'Bakery',
#                      'confidence': 0.1859504132231405},
#                     {'product': 'Ginger Biscotti',
#                      'product_category': 'Bakery',
#                      'confidence': 0.18181818181818182},
#                     {'product': 'Oatmeal Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.1790633608815427},
#                     {'product': 'Hazelnut Biscotti',
#                      'product_category': 'Bakery',
#                      'confidence': 0.17768595041322313},
#                     {'product': 'Hazelnut syrup',
#                      'product_category': 'Flavours',
#                      'confidence': 0.1763085399449036}],
#  'Almond Croissant': [{'product': 'Dark chocolate',
#                        'product_category': 'Packaged Chocolate',
#                        'confidence': 0.5117845117845118}],
#  'Carmel syrup': [{'product': 'Direct',
#                    'product_category': 'Coffee',
#                    'confidence': 0.3741339491916859},
#                   {'product': 'Espresso shot',
#                    'product_category': 'Coffee',
#                    'confidence': 0.3695150115473441},
#                   {'product': 'Cappucin',
#                    'product_category': 'Coffee',
#                    'confidence': 0.34642032332563516},
#                   {'product': 'Dark chocolate',
#                    'product_category': 'Packaged Chocolate',
#                    'confidence': 0.3371824480369515}],
#  'Cappucin': [{'product': 'Sugar Free Vanilla syrup',
#                'product_category': 'Flavours',
#                'confidence': 0.32553956834532377},
#               {'product': 'Chocolate syrup',
#                'product_category': 'Flavours',
#                'confidence': 0.3057553956834532},
#               {'product': 'Carmel syrup',
#                'product_category': 'Flavours',
#                'confidence': 0.2697841726618705},
#               {'product': 'Hazelnut syrup',
#                'product_category': 'Flavours',
#                'confidence': 0.2517985611510791}],
#  'Chocolate syrup': [{'product': 'Cappucin',
#                       'product_category': 'Coffee',
#                       'confidence': 0.38636363636363635},
#                      {'product': 'Espresso shot',
#                       'product_category': 'Coffee',
#                       'confidence': 0.3545454545454545},
#                      {'product': 'Direct',
#                       'product_category': 'Coffee',
#                       'confidence': 0.33409090909090905}],
#  'Hazelnut syrup': [{'product': 'Espresso shot',
#                      'product_category': 'Coffee',
#                      'confidence': 0.36962025316455693},
#                     {'product': 'Direct',
#                      'product_category': 'Coffee',
#                      'confidence': 0.3670886075949367},
#                     {'product': 'Cappucin',
#                      'product_category': 'Coffee',
#                      'confidence': 0.35443037974683544},
#                     {'product': 'Dark chocolate',
#                      'product_category': 'Packaged Chocolate',
#                      'confidence': 0.3240506329113924}],
#  'Sugar Free Vanilla syrup': [{'product': 'Cappucin',
#                                'product_category': 'Coffee',
#                                'confidence': 0.3934782608695652},
#                               {'product': 'Direct',
#                                'product_category': 'Coffee',
#                                'confidence': 0.3652173913043478},
#                               {'product': 'Espresso shot',
#                                'product_category': 'Coffee',
#                                'confidence': 0.3521739130434782}],
#  'Direct': [{'product': 'Sugar Free Vanilla syrup',
#              'product_category': 'Flavours',
#              'confidence': 0.302158273381295},
#             {'product': 'Carmel syrup',
#              'product_category': 'Flavours',
#              'confidence': 0.29136690647482016},
#             {'product': 'Chocolate syrup',
#              'product_category': 'Flavours',
#              'confidence': 0.2643884892086331},
#             {'product': 'Hazelnut syrup',
#              'product_category': 'Flavours',
#              'confidence': 0.26079136690647486}],
#  'Espresso shot': [{'product': 'Sugar Free Vanilla syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.294010889292196},
#                    {'product': 'Carmel syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.29038112522686027},
#                    {'product': 'Chocolate syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.2831215970961887},
#                    {'product': 'Hazelnut syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.26497277676951}],
#  'Chocolate Chip Biscotti': [{'product': 'Dark chocolate',
#                               'product_category': 'Packaged Chocolate',
#                               'confidence': 0.5035460992907802}],
#  'Chocolate Croissant': [{'product': 'Dark chocolate',
#                           'product_category': 'Packaged Chocolate',
#                           'confidence': 0.452991452991453}],
#  'Cranberry Scone': [{'product': 'Dark chocolate',
#                       'product_category': 'Packaged Chocolate',
#                       'confidence': 0.5016835016835016}],
#  'Croissant': [{'product': 'Dark chocolate',
#                 'product_category': 'Packaged Chocolate',
#                 'confidence': 0.4623287671232877}],
#  'Ginger Biscotti': [{'product': 'Dark chocolate',
#                       'product_category': 'Packaged Chocolate',
#                       'confidence': 0.4962406015037594}],
#  'Ginger Scone': [{'product': 'Dark chocolate',
#                    'product_category': 'Packaged Chocolate',
#                    'confidence': 0.4674556213017752}],
#  'Hazelnut Biscotti': [{'product': 'Dark chocolate',
#                         'product_category': 'Packaged Chocolate',
#                         'confidence': 0.4795539033457249}],
#  'Jumbo Savory Scone': [{'product': 'Dark chocolate',
#                          'product_category': 'Packaged Chocolate',
#                          'confidence': 0.47386759581881527}],
#  'Oatmeal Scone': [{'product': 'Dark chocolate',
#                     'product_category': 'Packaged Chocolate',
#                     'confidence': 0.4676258992805755}]}

# %%
import json
with open('api/recommendation_objects/apriori_recommendations.json', 'w') as json_file:
    json.dump(recommendations_json, json_file)
